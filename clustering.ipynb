# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import pairwise_distances_argmin_min
import json

# %% [markdown]
# Load TPSD data

# %%
FILE_PATH = './data/tpsd_seq_dict.json'
with open(FILE_PATH, 'r') as file:
    data = json.load(file)

sequences = list(data.values())
# Out:
# 32

# %% [markdown]
# Apply kmeans

# %%
# fit model
kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
kmeans.fit(X)

# assign a cluster to each data sample + select centroid
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_

# compute distances to centroid (to be used later to rank labels)
closest, distances = pairwise_distances_argmin_min(X, centroids)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Plot the result

# %%
# Plot the clustered data
plt.scatter(X[:, 0], X[:, 1], c=labels, marker='o', edgecolor='k')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=100)
plt.title("Clustered Data")
plt.show()

# Print the results
print("Cluster centroids:\n", centroids)
print("\nDistances to the nearest centroid for each sample:\n", distances)
# Out:
# Cluster centroids:
#  [[ 4.74710337  2.01059427]
#  [-6.88387179 -6.98398415]
#  [-2.63323268  9.04356978]]
#
# Distances to the nearest centroid for each sample:
#  [0.87384313 0.90100321 1.5680663  1.10996953 2.22581816 0.77595426
#  0.46378589 0.67441605 0.41511947 1.23795376 1.88453686 0.77187016
#  2.0166206  1.36747356 0.75147291 0.67934907 1.63039491 2.13756858
#  0.96503394 2.27508944 1.53869539 0.37661395 0.88728556 0.1593527
#  0.60018235 1.6351155  1.03253307 2.25373479 0.94228348 1.14023789
#  1.0514474  1.04972333 1.1235405  1.31909563 2.10856855 1.32531981
#  1.11762059 0.56152394 0.93702232 1.85364311 1.37841873 0.39543302
#  0.58452664 1.2207046  1.20128717 1.58492217 0.38139341 0.59425281
#  0.46013589 1.95270681 0.71527673 1.58382308 0.91456501 1.69292412
#  1.19588742 3.83704137 0.50942889 1.15305388 0.62473778 1.08155175
#  0.90702924 2.83937687 0.83707297 3.31700028 1.1029373  1.10357399
#  0.86294005 1.24676427 1.69982496 1.03815142 1.19836678 1.96668338
#  0.76467323 0.60593864 1.51667757 0.2798888  2.06325026 0.8736915
#  0.57461075 1.18587101 0.93336099 0.97563732 1.00921077 1.0500988
#  1.04325656 1.32583015 1.22557011 2.03886394 1.69847696 1.58331873
#  1.78652538 1.53789179 0.65187742 1.08171641 0.63154825 1.22420947
#  1.06407274 0.84481252 1.86266738 2.02423103 0.90336182 0.71738833
#  0.61708576 1.31089705 0.79124302 1.9767419  1.85232942 0.49077949
